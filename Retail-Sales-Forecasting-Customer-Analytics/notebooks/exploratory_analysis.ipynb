# %% [markdown]
# # Exploratory Analysis
# Generated notebook for the Retail Sales Forecasting & Customer Analytics Platform.

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv('../data/processed/superstore_processed.csv', parse_dates=['Order Date'])
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
