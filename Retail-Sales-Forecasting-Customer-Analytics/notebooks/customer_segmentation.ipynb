# %% [markdown]
# # Customer Segmentation
# Generated notebook for the Retail Sales Forecasting & Customer Analytics Platform.

# %%
import pandas as pd
from src.customer_analysis import segment_customers
df = pd.read_csv('../data/processed/superstore_processed.csv', parse_dates=['Order Date', 'Ship Date'])
customers, model, scaler = segment_customers(df)
customers.head()
