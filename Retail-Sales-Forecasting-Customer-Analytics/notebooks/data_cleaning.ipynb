# %% [markdown]
# # Data Cleaning
# Generated notebook for the Retail Sales Forecasting & Customer Analytics Platform.

# %%
from src.preprocessing import clean_superstore_data
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
df = clean_superstore_data(root / 'data/raw/train.csv', root / 'data/processed/superstore_processed.csv')
df.head()
